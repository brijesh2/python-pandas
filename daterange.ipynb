# %%
import pandas as pd
df = pd.read_csv("HistoricalAppl-one-month-nodates.csv")
df.head()
# Out:
#     close      volume     open    high     low
# 0  171.35  28,027,983  169.850  172.06  169.00
# 1  167.37    40382890  163.045  167.54  162.88
# 2  164.34    32483310  161.950  164.75  161.65
# 3  162.71    60774900  158.500  163.89  157.51
# 4  156.41    70583530  157.070  157.89  150.24

# %%
dat = pd.date_range(start="6/1/2017",end="7/3/2017",freq='B',name='date')
dat
# Out:
# DatetimeIndex(['2017-06-01', '2017-06-02', '2017-06-05', '2017-06-06',
#                '2017-06-07', '2017-06-08', '2017-06-09', '2017-06-12',
#                '2017-06-13', '2017-06-14', '2017-06-15', '2017-06-16',
#                '2017-06-19', '2017-06-20', '2017-06-21', '2017-06-22',
#                '2017-06-23', '2017-06-26', '2017-06-27', '2017-06-28',
#                '2017-06-29', '2017-06-30', '2017-07-03'],
#               dtype='datetime64[ns]', name=u'date', freq='B')

# %%
df.set_index(dat,inplace=True)
df
# Out:
#              close      volume     open      high       low
# date
# 2017-06-01  171.35  28,027,983  169.850  172.0600  169.0000
# 2017-06-02  167.37    40382890  163.045  167.5400  162.8800
# 2017-06-05  164.34    32483310  161.950  164.7500  161.6500
# 2017-06-06  162.71    60774900  158.500  163.8900  157.5100
# 2017-06-07  156.41    70583530  157.070  157.8900  150.2400
# 2017-06-08  155.15    54145930  160.290  161.0000  155.0300
# 2017-06-09  159.54    51467440  163.085  163.4000  159.0685
# 2017-06-12  163.03    68171940  154.830  163.7200  154.0000
# 2017-06-13  156.49    72215320  159.100  163.8800  156.0000
# 2017-06-14  160.50    85957050  166.000  166.8000  160.1000
# 2017-06-15  167.78    44453230  167.165  168.6200  166.7600
# 2017-06-16  167.43    32234520  166.870  168.4417  166.5000
# 2017-06-19  166.97    45635470  165.525  167.3700  164.7000
# 2017-06-20  167.96    50565420  170.160  170.1600  167.0700
# 2017-06-21  171.51    39075250  172.000  172.0000  170.0600
# ...

# %%
# %matplotlib inline
df.close.plot()

# %%
df["2017-06-01":"2017-06-10"].mean()
# Out:
# close    162.410000
# open     161.970000
# high     164.361429
# low      159.339786
# dtype: float64

# %%
df.asfreq('D',method='pad')#ffill or pad are same filling method on the place of nan
# Out:
#              close      volume     open      high       low
# date
# 2017-06-01  171.35  28,027,983  169.850  172.0600  169.0000
# 2017-06-02  167.37    40382890  163.045  167.5400  162.8800
# 2017-06-03  167.37    40382890  163.045  167.5400  162.8800
# 2017-06-04  167.37    40382890  163.045  167.5400  162.8800
# 2017-06-05  164.34    32483310  161.950  164.7500  161.6500
# 2017-06-06  162.71    60774900  158.500  163.8900  157.5100
# 2017-06-07  156.41    70583530  157.070  157.8900  150.2400
# 2017-06-08  155.15    54145930  160.290  161.0000  155.0300
# 2017-06-09  159.54    51467440  163.085  163.4000  159.0685
# 2017-06-10  159.54    51467440  163.085  163.4000  159.0685
# 2017-06-11  159.54    51467440  163.085  163.4000  159.0685
# 2017-06-12  163.03    68171940  154.830  163.7200  154.0000
# 2017-06-13  156.49    72215320  159.100  163.8800  156.0000
# 2017-06-14  160.50    85957050  166.000  166.8000  160.1000
# 2017-06-15  167.78    44453230  167.165  168.6200  166.7600
# ...
